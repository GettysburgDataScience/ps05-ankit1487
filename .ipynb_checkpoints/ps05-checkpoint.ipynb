# %%
## Ankit Daga Section A

# %% [markdown]
# DS 256 Data Science Programming, Fall 2024
#
# Prof Eatai Roth
#
# ## Problem Set 5
# Due 11/14/2024 by 8p

# %% [markdown]
# ## Titanic Pandas
# (sounds cute...is not)
#
# In this assignment, we'll explore the titanic training data set. These data represent a portion of the passenger manifest of the Titanic, detailing the passengers and whether or not they survived the fateful crash.
#
# The columns are mostly self-explanatory. Key to less-obvious columns:
#  - Sex - male=1 / female=0
#  - Parch - number of parents/children traveling with
#  - SibSp - numbers of siblings/spouses traveling with
#  - PClass - ticket class (like first class, business, economy)
#
#
#  To start, you should import packages, ```pandas``` (as pd) and ```matplotlib.pyplot``` (as plt). Then load the data from ```titanic_train_clean.csv``` into a pandas dataframe.
#
#  Feel free to add more code blocks if needed. When making figures, don't forget to label axes and provide titles and legends when appropriate.

# %%
# Add the boilerplate code for importing the required packages and data
import pandas as pd
import matplotlib.pyplot as plt
import os
import matplotlib as mpl

filepath = '/Users/ankitdaga/Desktop/DS256/Assignments/ps05-ankit1487/titanic.csv'
titanic = pd.read_csv(filepath)
titanic2 = pd.read_csv(filepath)
titanic2.dropna(inplace=True)

# %% [markdown]
# ## Homework Problems
#
# For each of the problems, you'll write some code to find the answer. If there is a written/short answer component, use the provided text field.

# %% [markdown]
# ### Problem 1
#
#  - How many passengers are recorded in this log?
#  - What percentage are male?
#  - What percentage survived?
#
# Hint: You can find these three answers with a single command.

# %%
'''your code here'''
print((titanic.PassengerId.count())) # counting the number of passengers after NA removal
print((titanic2.PassengerId.count())) # couunting the number of passengers without NA removal
# Out:
# 891
# 204

# %%
male = titanic.query("Sex == 1")
female = titanic.query("Sex == 0")
maleperc = (len(male.Sex)/len(titanic))*100
femaleperc = (len(female.Sex)/len(titanic))*100

print(maleperc) # percent of male 
print(femaleperc) # percent of female 

print(maleperc+femaleperc)
# Out:
# 64.75869809203144
# 35.24130190796858
# 100.00000000000001

# %% [markdown]
# Your written answer:
#
#  - it is 891 passengers if I dont remove datatypes that have NaN in them but it becomes 204 if I do
#  - 64.76%
#  - 35.24%

# %% [markdown]
# ### Problem 2:
#
#  - What percentage of female passengers survived?
#  - What percentage of male passengers survived?

# %%
'''your code here'''
malesurvive_perc = (len(male.query('Survived == 1'))/len(titanic))*100 # male survival percentage
#maledeath_perc = (len(male.query('Survived == 0'))/len(titanic))*100

femalesurvive_perc = (len(female.query('Survived == 1'))/len(titanic))*100 # female survivale percentage
#femaledeath_perc = (len(female.query('Survived == 0'))/len(titanic))*100

print(malesurvive_perc)
#print(maledeath_perc)

print(femalesurvive_perc)
#print(femaledeath_perc)
# Out:
# 12.2334455667789
# 26.15039281705948

# %% [markdown]
# Your written answer:
#
#  - 26.15% female survival percentage
#  - 12.23% male survival percentage

# %% [markdown]
# ### Problem 3
#
# Use ```groupby``` and ```agg``` to find the percentage of the total tickets and the survivorship percentage for each class of ticket.

# %%
'''your code here'''
tita_class = titanic.groupby('Pclass')

ticket_perc = (tita_class['Ticket'].count()/len(titanic))*100 # ticket percentage shown

print("Ticket percentage for each class: \n" + str(ticket_perc) + "  \n  ") 



tita2 = titanic.groupby(['Pclass', 'Survived']).agg(['count'])

survived_count = tita2.query('Survived == 1')['Ticket'] # total tickets for each class that survived
not_survived_count = tita2.query('Survived == 0')['Ticket']

survived_perc = (survive_count/len(titanic))*100 # %survivorship

print(" \n This is Survived count: "+ str(survived_count)+ '\n') 

print(" \n This is DEATH count: "+ str(not_survived_count)+ '\n') 

print(" \n This is Survive percentage" + str(survived_perc))
# Out:
# Ticket percentage for each class:
# Pclass
# 1    24.242424
# 2    20.650954
# 3    55.106622
# Name: Ticket, dtype: float64
#
#
#  This is Survived count:                  count
# Pclass Survived
# 1      1           136
# 2      1            87
# 3      1           119
#
#
#  This is DEATH count:                  count
# Pclass Survived
# 1      0            80
# 2      0            97
# 3      0           372
#
#
#  This is Survive percentage                     count
# Pclass Survived
# 1      1         15.263749
# 2      1          9.764310
# 3      1         13.355780

# %% [markdown]
# Your written answer:
#
#  - Class 1
#     - % tickets: 24.24%
#     - % survivorship: 15.26%
# - Class 2
#     - % tickets: 20.65%
#     - % survivorship: 9.76%
# - Class 3
#     - % tickets:  55.11%
#     - % survivorship: 13.35%

# %% [markdown]
# ### Problem 4
#
# Create two new dataframes corresponding to survivors and non-survivors keeping only the columns: age, name, and sex. Display the first five rows of these new dataframes.
#
# Create a figure showing the distribution of age by sex and survivorship (four histograms on the same axes: male-survivors, female-survivors, male-unlucky, female-unlucky). Choose colors and histtype (see the [documentation for histogram](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.hist.html)) to make this figure easy to read and interpret.

# %%
'''Your code here'''
survivors_column = titanic.query('Survived == 1').filter(['Age','Name','Sex'])

non_survivors_column = titanic.query('Survived == 0').filter(['Age','Name','Sex'])

print('This is the Survivor Dataframe')

survivors_column.head()
# Out:
# This is the Survivor Dataframe
# <class 'pandas.core.frame.DataFrame'>
#     Age                                               Name  Sex
# 1  38.0  Cumings, Mrs. John Bradley (Florence Briggs Th...    0
# 2  26.0                             Heikkinen, Miss. Laina    0
# 3  35.0       Futrelle, Mrs. Jacques Heath (Lily May Peel)    0
# 8  27.0  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)    0
# 9  14.0                Nasser, Mrs. Nicholas (Adele Achem)    0

# %%
print('This is the non-survivor Dataframe')
non_survivors_column.head()
# Out:
# This is the non-survivor Dataframe
#     Age                            Name  Sex
# 0  22.0         Braund, Mr. Owen Harris    1
# 4  35.0        Allen, Mr. William Henry    1
# 5  30.0                Moran, Mr. James    1
# 6  54.0         McCarthy, Mr. Timothy J    1
# 7   2.0  Palsson, Master. Gosta Leonard    1

# %%
import matplotlib.pyplot as plt
import numpy as np

male_survivors = survivors_column.query('Sex == 1')

female_survivors = survivors_column.query('Sex == 0')

#male_survivors.head()
#female_survivors.head()

male_unlucky = non_survivors_column.query('Sex == 1')

female_unlucky = non_survivors_column.query('Sex == 0')

#male_unlucky.head()
#female_unlucky.head()
# Out:
#      Age                                               Name  Sex
# 14  14.0               Vestrom, Miss. Hulda Amanda Adolfina    0
# 18  31.0  Vander Planke, Mrs. Julius (Emelia Maria Vande...    0
# 24   8.0                      Palsson, Miss. Torborg Danira    0
# 38  18.0                 Vander Planke, Miss. Augusta Maria    0
# 40  40.0     Ahlin, Mrs. Johan (Johanna Persdotter Larsson)    0

# %%
plt.figure(figsize=(14, 8))
plt.xlabel('Age', fontsize=12)
plt.ylabel('Frequency', fontsize=12)
plt.title('Age Distribution by Sex and Survivorship', fontsize=14)





plt.hist(male_survivors['Age'], label = 'male survivor', color = 'blue')
plt.hist(female_survivors['Age'], label = 'female survivor', color = 'green', alpha = 0.7)
plt.hist(male_unlucky['Age'], label = 'male dead', color = 'red', alpha = 0.7)
plt.hist(female_unlucky['Age'], label = 'female dead', color = 'yellow', alpha = 0.7)

plt.legend(fontsize=10)
plt.show()

# %% [markdown]
# ### Problem 5
#
# Now that we've inspected the data, let's build a classifier (you'll compare two models) that predicts which passengers survived. These are the steps you should take:
#
#  - Choose your features. The label will be survivorship.
#  - Split the data into training and test sets.
#  - Standardize the values using StandardScaler
#  - Choose two of the following model types: KNN, SVM, Decision Tree. Create those models and select hyper-parameters.
#  - Fit your models to the training data.
#  - Apply the fit models to create predictions from the test data.
#  - For each model, create a confusion matrix for the training and test data. You may want to revisit the hyper-parameters and re-fit the models.
#
#  - Answer the questions at the bottom of the code block.

# %%
'''Your code here'''
titanic_df = pd.read_csv('/Users/ankitdaga/Desktop/DS256/Assignments/ps05-ankit1487/titanic.csv')
features = ['Age', 'Sex', 'Pclass', 'Fare', 'Family_Size']
label = ['Survived']

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(titanic_df[features], titanic_df[label], test_size = 0.2)

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier

ss = StandardScaler()
ss.fit(X_train)

Xs_train = ss.transform(X_train)
Xs_test = ss.transform(X_test)

ys_train = y_train.values.ravel()
ys_test = y_test.values.ravel()


def plotDecisionBoundary(model, data = None, xy_lim = None, ax = None):

    import matplotlib.pyplot as plt
    import numpy as np
    
    if ax is None:
        fig, ax = plt.subplots(1,1, figsize = (5,5))
    else:
        fig = ax.get_figure()
    
    # Check if data or xy_lim is provided
    if data is None and xy_lim is None:
        raise ValueError('If data is None, xy_lim must be provided')
    elif xy_lim is not None:
        f0_min, f0_max, f1_min, f1_max = xy_lim[0][0], xy_lim[0][1], xy_lim[1][0], xy_lim[1][1]
    elif not data is None:
        X = data[0]
        y = data[1]
        f0_min, f0_max, f1_min, f1_max = min(X[:,0]), max(X[:,0]), min(X[:,1]), max(X[:,1])

    range0, range1 = f0_max-f0_min, f1_max-f1_min

    F0, F1 = np.meshgrid(np.linspace(f0_min-0.1*range0, f0_max+0.1*range0, 200), np.linspace(f1_min-0.1*range1, f1_max+0.1*range1, 200))
    F_grid = np.vstack([F0.ravel(), F1.ravel()]).transpose()

    labels = model.classes_
    label_nums = np.arange(len(labels))
    label_dict = dict(zip(labels, label_nums))

    y_grid = model.predict(F_grid)
    y_num_grid = np.array([label_dict[y_lab] for y_lab in y_grid]).reshape(F0.shape)

    cmap = plt.get_cmap('tab10', len(labels))
    ax.contourf(F0, F1, y_num_grid, cmap = cmap, alpha = 0.25)

    if not data is None:
        for label, label_num in zip(labels, label_nums):
            ax.scatter(X[y==label,0], X[y==label,1], label = label, s = 10, alpha = 0.75)
        ax.legend()
    plt.show()

    ax.set_xlabel('Feature 0')
    ax.set_ylabel('Feature 1')
    ax.set_aspect('equal')
    return fig, ax

# %%
knn_clf = KNeighborsClassifier(n_neighbors = 3)

knn_clf.fit(Xs_train, ys_train)

from sklearn.metrics import ConfusionMatrixDisplay

y_knn_train = knn_clf.predict(Xs_train)
y_knn_test = knn_clf.predict(Xs_test)

ConfusionMatrixDisplay.from_predictions(ys_train,y_knn_train, normalize = 'true', display_labels = ['Did not', 'Survived'])

ConfusionMatrixDisplay.from_predictions(ys_test,y_knn_test, normalize = 'true', display_labels = ['Did not', 'Survived'])

plt.show()

# %%
from sklearn.tree import DecisionTreeClassifier, plot_tree

tree_clf = DecisionTreeClassifier(max_depth = 4)
tree_clf.fit(Xs_train, ys_train)

fig, ax = plt.subplots(1, 2, figsize=(12, 6))

y_tree_train = tree_clf.predict(Xs_train)
y_tree_test = tree_clf.predict(Xs_test)

ConfusionMatrixDisplay.from_predictions(ys_test, y_knn_test, normalize = 'true', display_labels = ['Did not','Survived'], ax = ax[0])
ConfusionMatrixDisplay.from_predictions(ys_train, y_knn_train, normalize = 'true', display_labels = ['Did not','Survived'], ax = ax[1])

ax[0].set_title('Training')
ax[1].set_title('Test')
fig.suptitle('Decision tree')

plt.show()

# %%
plot_tree(tree_clf, class_names = ['Drowned', 'Survived'], feature_names = features, filled = True, fontsize = 6)

plt.show()

# %% [markdown]
# #### **Questions**
#
# How does the model performance on the test data compare to the performance on the training data?
#
#  - Decision Tree did better than Confusion Matrix.
#
#
# Which models did you fit and which worked better?
#
#  - Used Confusion matrix and Decision Tree and Decision Tree had a better, more accurate result.
